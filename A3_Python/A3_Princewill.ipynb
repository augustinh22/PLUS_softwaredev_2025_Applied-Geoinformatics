# %%
#The aim is to create a simple map with folium and python displaying a bike station location data .
#In this notebook, I will use folium to open a csv file, explore it and visualize it.

# %%
# !pip install pandas

# %%
# !pip install folium

# %%
#After importing the folium and pandas successfully on juypter notebook
# i also imported the libraries

# %%
#import ee and folium
import folium
import pandas as pd

# %%
#working on how to get the different bike station,create a simple map, and add points to each of the location using folium in python
#Getting the bike locations and saving to a data is done by Pandas, pandas allows us to import data from various file formats such as CSV,JSON etc

# %%
location = "https://data.smartdublin.ie/dataset/33ec9fe2-4957-4e9a-ab55-c5e917c7a9ab/resource/2dec86ed-76ed-47a3-ae28-646db5c5b965/download/dublin.csv"

# %%
bikes_station_locations = pd.read_csv(location)

# %%
bikes_station_locations
# Out:
#      Number                    Name                 Address   Latitude  \
# 0        42        SMITHFIELD NORTH        Smithfield North  53.349562
# 1        30    PARNELL SQUARE NORTH    Parnell Square North  53.353462
# 2        54          CLONMEL STREET          Clonmel Street  53.336021
# 3       108           AVONDALE ROAD           Avondale Road  53.359405
# 4        56      MOUNT STREET LOWER      Mount Street Lower  53.337960
# ..      ...                     ...                     ...        ...
# 105      39          WILTON TERRACE          Wilton Terrace  53.332383
# 106      83              EMMET ROAD              Emmet Road  53.340714
# 107      92  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)  53.347802
# 108      21   LEINSTER STREET SOUTH   Leinster Street South  53.342180
# 109      88         BLACKHALL PLACE         Blackhall Place  53.348800
#
#      Longitude
# 0    -6.278198
# 1    -6.265305
# 2    -6.262980
# 3    -6.276142
# 4    -6.241530
# ..         ...
# ...

# %%
#The bike stations has been imported.
#The Bikes_Stations_locations has a total of 110 data
#Now i need to keep the latitude and longitude and the Name of the Stations. 
#The last two columns will allow me to map the location and the Name will be use to give each location pin a name

# %%
bikes_station_locations = bikes_station_locations[["Latitude", "Longitude", "Name",]]

# %%
#The next step is to create the map of the stations using the location parameters.
#I zoomed to 15

# %%
map = folium.Map(location=[53.348800, -6.281637],zoom_start=15, control_scale=True)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for index, location_info in bikes_station_locations.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# these are the bikes stations locations in Dublin, but i can also change the color

# %%
map = folium.Map(location=[53.348800, -6.281637],zoom_start=15, control_scale=True)
#Loop through each rows in the dataframe
for i,rows in bikes_station_locations.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame(f'Name: {str(rows["Name"])} \n Name: {str(rows["Name"])}')
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    try:
        icon_color = Name_colour[rows['Name']]
    except:
        #Catch nans
        icon_color = 'red'
    
    #Add each row to the map
    folium.Marker(location=[rows['Latitude'],rows['Longitude']],
                  popup = popup, 
                  icon=folium.Icon(color=icon_color, icon='')).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Now I add the points for each bike station location to the map. Iterating through each row of the dataframe, I pass the location latitude and longitudes to folium.
#Marker as a list and pass the name to the popup parameter. And for each location I add to map:

# %%
marker_location = [53.349562, -6.278198]
tooltip = "I am a tooltip!"

folium.Marker(
    marker_location, popup=popup, tooltip=tooltip
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
DOCMENTATION
Folium: https://python-visualization.github.io/folium/
Pandas: https://pandas.pydata.org/docs/user_guide/index.html
DATA: https://data.smartdublin.ie/dataset/33ec9fe2-4957-4e9a-ab55-c5e917c7a9ab/resource/2dec86ed-76ed-47a3-ae28-646db5c5b965/download/dublin.csv
    
TASK How to show the Bikes_Station_in_Dublin.
create a simple map, and add points to it for each location using Folium in Python. Map will be displayed and with a map marker

    
RESOURCES
https://towardsdatascience.com/folium-mapping-displaying-markers-on-a-map-6bd56f3e3420#:~:text=Adding%20a%20Single%20Marker%20to,and%20longitude%20of%20our%20data.
